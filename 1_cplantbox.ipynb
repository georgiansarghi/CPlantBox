# %% [markdown]
# # Structure definition and analysis

# %%
import sys, sysconfig

site = sysconfig.get_paths()["platlib"]
sys.path[:] = [site] + [p for p in sys.path if "CPlantBox" not in p]
import os
import plantbox as pb
import vtk_plot as vp
import matplotlib.pyplot as plt
import numpy as np

doInteractiveImage = True

# %% [markdown]
# ## 1. Simulate a root system

# %%
# Create instance describing a root system
rs = pb.Plant()
verbose = False
# Open plant and root parameter from a packaged file (portable)
param_root = os.path.join(pb.data_path(), "structural", "rootsystem")
name = "Anagallis_femina_Leitner_2010"
rs.readParameters(os.path.join(param_root, name + ".xml"))
# or (re)defined in python
# rs.getOrganRandomParameter(pb.root,4).lmax = 20 # [cm] maximum root length

# Simulate
rs.initialize(verbose)
rs.simulate(30, verbose)  # [days]

# Export
rs.write("first_example.vtp")  # for Paraview
rs.write("first_example.rsml")  # e.g. gui/viewer/rsml_viewer.py

# Visualize
# _ = vp.plot_roots(
#     rs, "subType", interactiveImage=doInteractiveImage
# )  # Plot, using vtk (e.g. "radius")
# Out:
# writing VTP... first_example.vtp
# writing RSML... first_example.rsml

# %% [markdown]
# ## 2. Post-processing (how to evaluate simulation results)
#
# There are two main methods
#
# 1. Using class *Plant* directly, parameter values are organised per organ.
#
# 2. Using class *SegmentAnalyser*, parameter values are organised per nodes and segments.

# %% [markdown]
# ### 2.1 Root system length vs time

# %% [markdown]
# A typical simulation loop will look like

# %%
rs = pb.Plant()
param_root = os.path.join(pb.data_path(), "structural", "rootsystem")
name = "Zea_mays_1_Leitner_2010"
rs.readParameters(os.path.join(param_root, name + ".xml"))
rs.setGeometry(
    pb.SDF_PlantBox(1.0e6, 1.0e6, 1.0e6)
)  # where can the roots grow (shoot is not affected)
verbose = False
rs.initialize(verbose)

""" Simulation loop """
simtime = 60.0  # final simulation time [day]
dt = 1.0  # time step [day]
N = round(simtime / dt)  # number of iterations

for i in range(0, N):
    # Coupling to plant functional models or soil

    rs.simulate(dt, verbose)

    # Coupling to plant functional models or soil

    # Code for post-processing per time step (e.g. store relevant information in a list)


# Code for post-processing of the final result (write relevant results, e.g. csv, xls, etc.)
# _ = vp.plot_roots(rs, "creationTime", interactiveImage=doInteractiveImage)  # Plot, using vtk

# %% [markdown]
# The following example will plot length versus time for the root system, and each subType (see *example2d_length.py*)

# %%
rs.initialize()  # reset above simulation
scalar_type = "length"  # "surface", "volume"
v_, v1_, v2_, v3_, v4_ = np.zeros(N), np.zeros(N), np.zeros(N), np.zeros(N), np.zeros(N)

""" Simulation loop """
for i in range(0, N):
    rs.simulate(dt)
    t = np.array(rs.getParameter("subType"))  # value per root
    v = np.array(rs.getParameter(scalar_type))  # all random or specific parameters are accessible
    v_[i] = np.sum(v)
    v1_[i] = np.sum(v[t == 1])
    v2_[i] = np.sum(v[t == 2])
    v3_[i] = np.sum(v[t == 3])
    v4_[i] = np.sum(v[t == 4])

t_ = np.linspace(dt, N * dt, N)
plt.plot(t_, v_, t_, v1_, t_, v2_, t_, v3_, t_, v4_)
plt.xlabel("time (days)")
plt.ylabel(scalar_type + " (cm)")
plt.legend(["total", "tap root", "lateral", "2nd order lateral", "basal roots"])
# plt.savefig("myplot.png") # we could save it as png
plt.show()
print("final tap root length: ", v1_[-1], "cm")
# Out:
# Seed::initialize: Plant
# Seed::initialize: Basal root type #4 was not defined, using tap root parameters instead
# final tap root length:  2715.474465684896 cm

# %% [markdown]
# ## 2.2 Analyse results from the class *SegmentAnalyser* (values per segment) in a loop
#
# The main functionality of the *SegmentAnalyser* class is:
# * analyse several organisms at once
# * *getParameter(name)* as for *Plant* class
# * *filter(name, min, max)* will keep only segments where the value of parameter *name* is within [min, max]
# * *crop(sdf)* will keep only segments inside a geometry (e.g. in a soil core), segments intersecting the domain boundary are cut.
# * *distribution(...)* will create a 1d plot versus depth, where parameters are summed in layers
# * *distribution2d(...)* as above but 2d
# * *mapPeriodic(length, width)* maps the unconstrained root system into a periodic domain
# * *addData(name, data)* attach user data to the segments (e.g. simulation results for visualization or export)
#
# Note that *SegmentAnalyser* is only loosly connected to the original simulation.
#
# The first example shows how to obtain a depth distribution (values per segment) in a simulation loop.

# %%
def createPlant(y=0, depth=1e6, width=1e6):
    rs = pb.Plant()
    param_root = os.path.join(pb.data_path(), "structural", "rootsystem")
    name = "Lupinus_albus_Leitner_2014"
    rs.readParameters(os.path.join(param_root, name + ".xml"))
    rectangle = False
    rs.setGeometry(pb.SDF_PlantContainer(width, width, depth, rectangle))
    rs.getOrganRandomParameter(pb.seed, 0).seedPos.y = y

    verbose = False
    rs.initialize(verbose)
    return rs


depth = 50.0  # cm
layers = 60  # [1]
width = 10.0
rs = createPlant(0, depth, width)
rs2 = createPlant(8, depth, width)

simtimes = [0, 10, 20, 40, 60]  # day
dt_ = np.diff(simtimes)  # day

""" Simulation loop """
rsd_ = []
for dt in dt_:
    rs.simulate(dt, verbose)
    rs2.simulate(dt, verbose)
    ana = pb.SegmentAnalyser(rs)  # create a SegmentAnalyser object
    ana.addSegments(rs2)  # adding a second root system
    rsd = ana.distribution("surface", 0.0, -depth, layers, True)
    rsd_.append(rsd)  # store relevant data in a list

""" vizualize rld_ """
soilvolume = (depth / layers) * (width**2)
rsd_ = np.array(rsd_) / soilvolume  # convert to density [cm2/cm3]

z_ = np.linspace(0, -depth, layers)  # z - axis
for i, t in enumerate(simtimes[1:]):
    plt.plot(rsd_[i, :], z_, label="at time " + str(t))

plt.xlabel("root surface (cm^2 / cm^3)")
plt.ylabel("z-coordinate (cm)")
plt.legend()
# plt.savefig("surface_density.png")
plt.show()
# _ = vp.plot_roots(ana, "subType", interactiveImage=doInteractiveImage)  # final result

# %% [markdown]
# ## 3. Simulate a full plant

# %% [markdown]
# The definition of full plants is similar to that of root systems. Only, there are new parameters to take into account.

# %%
# create a plant from a parameter file
plant = pb.MappedPlant()
param_root = os.path.join(pb.data_path(), "structural", "plant")
name = "fspm2023"
plant.readParameters(os.path.join(param_root, name + ".xml"))

# choose which organ parameters to overwrite
adaptSeed = False  # change seed parameter
adaptRoot = False  # change seed parameter
adaptLeaf = False  # change leaf parameter
leafRadial = False  # radial or not
adaptStem = False  # change stem parameters
radialLeafShapeOptions = ["long", "maple", "round", "flower"]
radialLeafShape = radialLeafShapeOptions[3]

# %% [markdown]
# Within the seed parameters are defined the number of tillers and basal roots. Roots and stems are (among others) defined according to their maximal lengths, growth rate and the distance between two children organs (roots, stems or leaves growing out of the organ in question).

# %%
if adaptSeed:
    srp = pb.SeedRandomParameter(plant)  # with default values
    srp.firstTil = 0  # [day] first emergence of a tiller
    srp.delayTil = 0  # [day] delay between the emergence of tillers
    srp.maxTil = 20  # [-] number of tillers
    srp.firstB = 0  # [day] first emergence of a basal roots
    srp.delayB = 0  # [day] delay between the emergence of basal roots
    srp.maxB = 20  # [-] number of basal roots
    plant.setOrganRandomParameter(srp)
if adaptRoot:
    for p in plant.getOrganRandomParameter(pb.root):  # we go through the root subtypes
        p.dxMin = 0.01  # resolution == minimum segment length
        p.dx = 0.1  # resolution == maximum segment length
        if p.subType == 1:  # to which root subtype are the changes applied? Here: tap roots
            p.r = 10  # [cm/day] growth rate
            p.lmax = 20  # [cm] maximum length
            p.ln = 1  # [cm] interlateral distance
        plant.setOrganRandomParameter(p)
if adaptStem:
    for p in plant.getOrganRandomParameter(pb.stem):
        p.dxMin = 0.01  # resolution == minimum segment length
        p.dx = 0.1  # resolution == maximum segment length
        p.r = 10  # [cm/day] growth rate
        p.lmax = 20  # [cm] maximum length
        p.ln = 1  # [cm] interlateral distance
        plant.setOrganRandomParameter(p)

# %% [markdown]
# The leaf parameters can be adapted to represent different leaf 2D shapes. The 2D shapes can be defined according to the distance from the leaf center vain (non-radial geometry) or according to the distance from the leaf center (radial geometry).

# %%
if adaptLeaf:
    for p in plant.getOrganRandomParameter(pb.leaf):
        if leafRadial:
            if radialLeafShape == "long":
                p.lb = 1  # length of leaf stem
                p.la, p.lmax = 3.5, 8.5
                p.areaMax = 10  # cm2, area reached when length = lmax
                N = 100  # resolution of the leaf shape
                phi = np.array([-90, -45, 0.0, 45, 90]) / 180.0 * np.pi
                l = np.array([3, 2.2, 1.7, 2, 3.5])  # distance from leaf center

            elif radialLeafShape == "maple":
                p.lb = 1  # length of leaf stem
                N = 100  # resolution of the leaf shape
                p.areaMax = 50
                p.la, p.lmax = 5, 11
                phi = np.array([-90, -45, 0.0, 45, 67.5, 70, 90]) / 180.0 * np.pi
                l = np.array([2, 2, 2, 4, 1, 1, 4])  # distance from leaf center

            elif radialLeafShape == "round":
                p.lb = 1  # length of leaf stem
                N = 100  # resolution of the leaf shape
                p.la, p.lmax = 5, 11
                p.areaMax = 3.145 * (((p.lmax - p.la - p.lb) / 2) ** 2)
                phi = np.array([-90, -45, 0.0, 45, 67.5, 70, 90]) / 180.0 * np.pi
                l_ = (p.lmax - p.lb - p.la) / 2
                l = np.array([l_ for x_i in range(len(phi))])

            elif radialLeafShape == "flower":
                N = 100  # resolution of the leaf shape
                p.areaMax = 100
                p.la, p.lb, p.lmax = 5, 1, 11
                phi = np.array([-90.0, -67.5, -45, -22.5, 0, 22.5, 45, 67.5, 90]) / 180.0 * np.pi
                l = np.array([5.0, 1, 5, 1, 5, 1, 5, 1, 5])

            p.createLeafRadialGeometry(phi, l, N)

        else:
            p.parametrisationType = 1
            p.lb = 2  # length of leaf sheath
            p.la, p.lmax = 3.5, 8.5
            p.areaMax = 10  # cm2, area reached when length = lmax
            N = 100
            y = np.array([-3, -2.1, 0.0, 2.45, 3.5])
            l = np.array([0.0, 1.54, 1.7, 1.26, 0.0])
            p.createLeafGeometry(y, l, N)

        p.tropismT = 1  # 1: gravitropism
        # p.tropismN = 5
        # p.tropismS = 0.1
        plant.setOrganRandomParameter(p)

# %% [markdown]
# CPlantBox offers the option to print several vtk files to create a video of the growth in Paraview. When running the simulation on Colab, it is possible to print images at regular intervals.

# %%
verbose = False
from importlib import reload

vp = reload(vp)
plant.initialize(verbose)

# Simulate
if doInteractiveImage:
    dt = 1
    min_ = np.array([-20, -20, -50])
    max_ = np.array([20, 20, 30.0])
    anim = vp.AnimateRoots(plant)
    anim.min = min_
    anim.max = max_
    anim.res = [1, 1, 1]
    # anim.file = "./example_plant"
    # anim.avi_name = "./example_" # to save the resutls
    anim.plant = True
    anim.start()

    for i in range(0, int(30 / dt)):
        plant.simulate(dt, False)
        anim.root_name = "organType"
        anim.update()
else:
    plant.simulate(30, verbose)

# Plot, using vtk
vp.plot_plant(plant, "organType", interactiveImage=doInteractiveImage)

# zoom on one leaf--theoreticall 2D shape once fully grown
leaves = plant.getOrgans(pb.leaf)
if len(leaves) > 0:
    print("2D leaf shape of a full grown leaf")
    lorg = leaves[0]
    lrp = lorg.getLeafRandomParameter()
    if leafRadial:
        yy = np.linspace(0, lorg.leafLength(), N)
        geom_x, geom_y = [], []
        for i, x in enumerate(lrp.leafGeometry):
            geom_x.extend(x)
            geom_y.extend([yy[i]] * len(x))
        geom_x = np.array(geom_x)
        geom_y = np.array(geom_y)
        a = lorg.leafArea() / lorg.leafLength()  # scale radius
        plt.plot(geom_x * a, geom_y, "g*")
        plt.plot(-geom_x * a, geom_y, "g*")

    else:
        geom_x_a = np.array([0])
        geom_x_b = np.array([x[-1] for x in lrp.leafGeometry])  # normalized x value along length
        geom_x = np.concatenate((geom_x_a, geom_x_b))
        geom_y_a = np.array([0])
        geom_y_b = np.linspace(lrp.lb, lorg.leafLength() + lrp.lb, len(geom_x_b))
        geom_y = np.concatenate((geom_y_a, geom_y_b))
        a = lorg.leafArea() / lorg.leafLength()  # scale radius
        plt.plot(geom_x * a, geom_y, "g-*")
        plt.plot(-geom_x * a, geom_y, "g-*")
    plt.ylim([0, lrp.lmax + 1])
    plt.xlim([-a - 1, a + 1])
    plt.axis('scaled')
    plt.show()
else:
    print("no leaves created")
# Out:
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x153a55930> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x105f809b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f193b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x153aed5b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f39430> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f39a30> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f39cf0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3a5f0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3abf0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3b0f0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3b830> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3c2b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3c670> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3cf30> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3da30> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3e1f0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3eb30> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3f630> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f3f630> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f40270> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x153a48070> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f40af0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f418b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f41df0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f42470> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f43330> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f436b0> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f44570> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f44570> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f45730> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f46630> <class 'plantbox._plantbox.SegmentAnalyser'>
# plot_plant: ana <plantbox._plantbox.SegmentAnalyser object at 0x154f41b70> <class 'plantbox._plantbox.SegmentAnalyser'>
# 2D leaf shape of a full grown leaf
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# A more realistic representation is possible via coupling with Unreal Engine.
#
# Dirk N Baker et al. (2024) A scalable pipeline to create synthetic datasets from functional–structural plant models for deep learning, in silico Plants, https://doi.org/10.1093/insilicoplants/diad022
